# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
cov = pd.read_csv('C:\\Users\\HARUKA\\Desktop\\Aj.Ton\\python_dataviz\\2019_nCoV_data.csv')

# %%
cov.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
cov.shape
# Out:
# (1719, 8)

# %%
cov.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
cov['Province/State'].fillna('Unknow',inplace=True)

# %%
cov.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
cov.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State    False
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
covid=cov[['Country','Province/State','Confirmed','Deaths','Recovered']]
covid.head()
# Out:
#   Country Province/State  Confirmed  Deaths  Recovered
# 0   China          Anhui        1.0     0.0        0.0
# 1   China        Beijing       14.0     0.0        0.0
# 2   China      Chongqing        6.0     0.0        0.0
# 3   China         Fujian        1.0     0.0        0.0
# 4   China          Gansu        0.0     0.0        0.0

# %%
covid.isnull().any()
# Out:
# Country           False
# Province/State    False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
cov1 = covid.groupby(['Country','Province/State']).mean().reset_index()
cov1
# Out:
#                   Country   Province/State  Confirmed  Deaths  Recovered
# 0               Australia  New South Wales   4.000000     0.0   2.181818
# 1               Australia       Queensland   3.900000     0.0   0.000000
# 2               Australia  South Australia   2.000000     0.0   0.117647
# 3               Australia           Unknow   2.666667     0.0   0.000000
# 4               Australia         Victoria   3.454545     0.0   0.909091
# ..                    ...              ...        ...     ...        ...
# 116                    US      Seattle, WA   1.000000     0.0   0.529412
# 117                    US        Tempe, AZ   1.000000     0.0   0.000000
# 118                    US       Washington   1.000000     0.0   0.000000
# 119  United Arab Emirates           Unknow   6.300000     0.0   0.750000
# 120               Vietnam           Unknow   8.653846     0.0   2.192308
#
# [121 rows x 5 columns]

# %%
cov1.to_csv('Cov19.csv')

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
covid19=covid.iloc[:,:]

# %%
covid19
# Out:
#      Country   Province/State  Confirmed  Deaths  Recovered
# 0      China            Anhui        1.0     0.0        0.0
# 1      China          Beijing       14.0     0.0        0.0
# 2      China        Chongqing        6.0     0.0        0.0
# 3      China           Fujian        1.0     0.0        0.0
# 4      China            Gansu        0.0     0.0        0.0
# ...      ...              ...        ...     ...        ...
# 1714      US      Madison, WI        1.0     0.0        0.0
# 1715      US       Orange, CA        1.0     0.0        0.0
# 1716      US  San Antonio, TX        1.0     0.0        0.0
# 1717      US      Seattle, WA        1.0     0.0        1.0
# 1718      US        Tempe, AZ        1.0     0.0        0.0
#
# [1719 rows x 5 columns]

# %%
plt.bar(cov1.iloc[:,1],cov1.iloc[:,2])
plt.title(u'Covid-19',fontname='Tahoma',fontsize='20')
plt.xlabel('Province/State')
plt.ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %%
covid19_np=covid19.iloc[:50,:-1].to_numpy()
covid19_np[:8,:]
# Out:
# array([['China', 'Anhui', 1.0, 0.0],
#        ['China', 'Beijing', 14.0, 0.0],
#        ['China', 'Chongqing', 6.0, 0.0],
#        ['China', 'Fujian', 1.0, 0.0],
#        ['China', 'Gansu', 0.0, 0.0],
#        ['China', 'Guangdong', 26.0, 0.0],
#        ['China', 'Guangxi', 2.0, 0.0],
#        ['China', 'Guizhou', 1.0, 0.0]], dtype=object)

# %%
plt.scatter(covid19_np[:,1],covid19_np[:,2])

# %%
import matplotlib.pyplot as plt
cov1.plot(kind='bar',x='Province/State',y='Confirmed')
plt.show()
